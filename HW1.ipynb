# %% [markdown]
# 1. Pick one of the datasets from the ChatBot session(s) of the TUT demo (or from your own ChatBot session if you wish) and use the code produced through the ChatBot interactions to import the data and confirm that the dataset has missing values

# %% [markdown]
# Here is the description with chatbot: https://chatgpt.com/share/ca030d81-7a11-4be5-8d3a-719b4989a843

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2020/2020-05-05/villagers.csv"
df = pd.read_csv(url)
df.isna().sum()
# Out:
# row_n           0
# id              1
# name            0
# gender          0
# species         0
# birthday        0
# personality     0
# song           11
# phrase          0
# full_id         0
# url             0
# dtype: int64

# %% [markdown]
# 2. Start a new ChatBot session with an initial prompt introducing the dataset you're using and request help to determine how many columns and rows of data a pandas DataFrame has, and then
# use code provided in your ChatBot session to print out the number of rows and columns of the dataset; and,
# write your own general definitions of the meaning of "observations" and "variables" based on asking the ChatBot to explain these terms in the context of your dataset

# %%
import pandas as pd

# Load the dataset
url = "https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2020/2020-05-05/villagers.csv"
df = pd.read_csv(url)

# Get the number of rows and columns
num_rows, num_columns = df.shape

print(f"Number of rows: {num_rows}")
print(f"Number of columns: {num_columns}")
# Out:
# Number of rows: 391
# Number of columns: 11

# %% [markdown]
# 3. Ask the ChatBot how you can provide simple summaries of the columns in the dataset and use the suggested code to provide these summaries for your dataset

# %%
df.describe()
# Out:
#             row_n
# count  391.000000
# mean   239.902813
# std    140.702672
# min      2.000000
# 25%    117.500000
# 50%    240.000000
# 75%    363.500000
# max    483.000000

# %% [markdown]
# df.describe() will provide simpel summaries of the collums in the dataset.

# %%
df
# Out:
#      row_n        id      name  gender    species birthday personality  \
# 0        2   admiral   Admiral    male       bird     1-27      cranky
# 1        3   agent-s   Agent S  female   squirrel      7-2       peppy
# 2        4     agnes     Agnes  female        pig     4-21        uchi
# 3        6        al        Al    male    gorilla    10-18        lazy
# 4        7   alfonso   Alfonso    male  alligator      6-9        lazy
# ..     ...       ...       ...     ...        ...      ...         ...
# 386    475    winnie    Winnie  female      horse     1-31       peppy
# 387    477  wolfgang  Wolfgang    male       wolf    11-25      cranky
# 388    480      yuka      Yuka  female      koala     7-20      snooty
# 389    481      zell      Zell    male       deer      6-7        smug
# 390    483    zucker    Zucker    male    octopus      3-8        lazy
#
#                 song    phrase            full_id  \
# 0         Steep Hill   aye aye   villager-admiral
# ...

# %%
df['name'].value_counts()
# Out:
# name
# Admiral    1
# Muffy      1
# Paula      1
# Patty      1
# Pate       1
#           ..
# Elvis      1
# Eloise     1
# Elmer      1
# Ellie      1
# Zucker     1
# Name: count, Length: 391, dtype: int64

# %% [markdown]
# 4. If the dataset you're using has (a) non-numeric variables and (b) missing values in numeric variables, explain (perhaps using help from a ChatBot if needed) the discrepancies between size of the dataset given by df.shape and what is reported by df.describe() with respect to (a) the number of columns it analyzes and (b) the values it reports in the "count" column

# %%
df.shape
# Out:
# (391, 11)

# %%
df.describe()
# Out:
#             row_n
# count  391.000000
# mean   239.902813
# std    140.702672
# min      2.000000
# 25%    117.500000
# 50%    240.000000
# 75%    363.500000
# max    483.000000

# %% [markdown]
# df.shape only gives # of columns and rows.df.describe() provides summary of all statistics.

# %% [markdown]
# 5. Use your ChatBot session to help understand the difference between the following and then provide your own paraphrasing summarization of that difference

# %% [markdown]
# An attribute represents a value of a subject, meanwhile, a method is a function that is accociated with an object.

# %% [markdown]
# 6. The df.describe() method provides the 'count', 'mean', 'std', 'min', '25%', '50%', '75%', and 'max' summary statistics for each variable it analyzes. Give the definitions (perhaps using help from the ChatBot if needed) of each of these summary statistics

# %% [markdown]
# count: The # of non-missing values.
# Mean: The average value in the columns.
# Std: The measure of spread value round the mean values.
# Min: The minimum value within the column.
# 25%: The values that are below where the 25% of the data is.
# 50%: The values that are below where the 50% of the data is.
# 75%: The values that are below where the 75% of the data is.
# Max: Thr maximum value within the column.

# %% [markdown]
# 7. Missing data can be considered "across rows" or "down columns". Consider how df.dropna() or del df['col'] should be applied to most efficiently use the available non-missing data in your dataset and briefly answer the following questions in your own words.
# 1. We use df.dropna() will remove the entire column that has missing values. We should use it first when our missing value is more centralized.
# 2. we use del df.['col'] to remove all irrevalent columns.We should use it first when or missing values are more separated.
# 3. We apply both together becasue it is more efficient as it can make a smaller dataset size.
# 4.

# %%
df
# Out:
#      row_n        id      name  gender    species birthday personality  \
# 0        2   admiral   Admiral    male       bird     1-27      cranky
# 1        3   agent-s   Agent S  female   squirrel      7-2       peppy
# 2        4     agnes     Agnes  female        pig     4-21        uchi
# 3        6        al        Al    male    gorilla    10-18        lazy
# 4        7   alfonso   Alfonso    male  alligator      6-9        lazy
# ..     ...       ...       ...     ...        ...      ...         ...
# 386    475    winnie    Winnie  female      horse     1-31       peppy
# 387    477  wolfgang  Wolfgang    male       wolf    11-25      cranky
# 388    480      yuka      Yuka  female      koala     7-20      snooty
# 389    481      zell      Zell    male       deer      6-7        smug
# 390    483    zucker    Zucker    male    octopus      3-8        lazy
#
#                 song    phrase            full_id  \
# 0         Steep Hill   aye aye   villager-admiral
# ...

# %%
df.dropna()
# Out:
#      row_n        id      name  gender    species birthday personality  \
# 0        2   admiral   Admiral    male       bird     1-27      cranky
# 1        3   agent-s   Agent S  female   squirrel      7-2       peppy
# 2        4     agnes     Agnes  female        pig     4-21        uchi
# 3        6        al        Al    male    gorilla    10-18        lazy
# 4        7   alfonso   Alfonso    male  alligator      6-9        lazy
# ..     ...       ...       ...     ...        ...      ...         ...
# 386    475    winnie    Winnie  female      horse     1-31       peppy
# 387    477  wolfgang  Wolfgang    male       wolf    11-25      cranky
# 388    480      yuka      Yuka  female      koala     7-20      snooty
# 389    481      zell      Zell    male       deer      6-7        smug
# 390    483    zucker    Zucker    male    octopus      3-8        lazy
#
#                 song    phrase            full_id  \
# 0         Steep Hill   aye aye   villager-admiral
# ...

# %% [markdown]
# Before: There are more rows
# After: There are less rows because all missing rows have been deleted

# %%
df.dropna(axis=1)
# Out:
#      row_n      name  gender    species birthday personality    phrase  \
# 0        2   Admiral    male       bird     1-27      cranky   aye aye
# 1        3   Agent S  female   squirrel      7-2       peppy  sidekick
# 2        4     Agnes  female        pig     4-21        uchi   snuffle
# 3        6        Al    male    gorilla    10-18        lazy   Ayyeeee
# 4        7   Alfonso    male  alligator      6-9        lazy  it'sa me
# ..     ...       ...     ...        ...      ...         ...       ...
# 386    475    Winnie  female      horse     1-31       peppy    hay-OK
# 387    477  Wolfgang    male       wolf    11-25      cranky   snarrrl
# 388    480      Yuka  female      koala     7-20      snooty   tsk tsk
# 389    481      Zell    male       deer      6-7        smug     pronk
# 390    483    Zucker    male    octopus      3-8        lazy     bloop
#
#                full_id                                                url
# ...

# %% [markdown]
# Before：There are more columns
# After: There are less columns becasue columns with missing values have been deleted.

# %% [markdown]
# 8. Give brief explanations in your own words for any requested answers to the questions below

# %% [markdown]
# 1.

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanic.csv"
df = pd.read_csv(url)
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
x = df.groupby("class")["age"].describe()

print(x)
# Out:
#         count       mean        std   min   25%   50%   75%   max
# class
# First   186.0  38.233441  14.802856  0.92  27.0  37.0  49.0  80.0
# Second  173.0  29.877630  14.001077  0.67  23.0  29.0  36.0  70.0
# Third   355.0  25.140620  12.495398  0.42  18.0  24.0  32.0  74.0

# %% [markdown]
# df.groupby('col1')['col2'].describe()
# It will group the df be all strenge value in col1
# and it will choose col2 from each different gorups
# lastly, it will provide statisticall summary for col2 in each different group.

# %% [markdown]
# 2. for 'count' in df.describe(), it will present as the # of non - missing value in each column of the entire df.
#    For df.groupby("col1")["col2"].describe(), it shows all non- missing value in column2 with in the group of column1.

# %% [markdown]
# 3. After tesing value from A to G. I discovered that Chatgpt will instanly provide solutions and explain the issue. On the other hands, google could not understand my question and always provide websites or links that are irrelavent. Therefore, using chatgpt for troubleshooting coding errors is better than google search.

# %% [markdown]
# 9. Have you reviewed the course wiki-textbook and interacted with a ChatBot (or, if that wasn't sufficient, real people in the course piazza discussion board or TA office hours) to help you understand all the material in the tutorial and lecture that you didn't quite follow when you first saw it?
#
#     Yes, I have mostly used wiki-textbook and interacted with chatgpt for gaining my understand of how python works when dealing with datasets and dateframes.
